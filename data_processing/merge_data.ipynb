# %%
import os

# Get the current working directory and go up one level to reach root
DATA_DIR = os.path.join(os.getcwd(), '..', 'data')
print(f"Data directory: {DATA_DIR}")

import pandas as pd
import json
from datetime import datetime, timedelta

# Add this to help Python find the module
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))
from health_data import fetch_garmin_health_data

# Verify the path exists
if not os.path.exists(DATA_DIR):
    print(f"Warning: Data directory not found at {DATA_DIR}")
else:
    print(f"Successfully located data directory at {DATA_DIR}")
# Out:
# Data directory: /Users/maudhelenhovland/Desktop/AffectiveLamp/data_processing/../data
# Successfully located data directory at /Users/maudhelenhovland/Desktop/AffectiveLamp/data_processing/../data

# %%
app_data = pd.read_csv('/Users/maudhelenhovland/Desktop/AffectiveLamp/my-va-app/data/emotion_data.csv')
print("Successfully loaded app data")
display(app_data.head())
print("\nApp data shape:", app_data.shape)

# #Drop the hue sat and bri columns
# app_data = app_data.drop(columns=['hue', 'saturation', 'brightness'])
# display(app_data.head())
# print("\nApp data shape:", app_data.shape)
# Out:
# Successfully loaded app data
#               timestamp   valence   arousal  emotion    hue  saturation  \
# 0  2025-03-27T17:18:00Z  0.537143  0.451429    Happy  21845         254
# 1  2025-03-27T17:20:00Z  0.565714  0.245714    Happy  21845         254
# 2  2025-03-27T17:20:00Z  0.645714  0.474286    Happy  21845         254
# 3  2025-03-27T17:30:00Z  0.466878  0.884322  Excited  21845         254
# 4  2025-03-27T17:32:00Z  0.754286  0.377143    Happy  21845         254
#
#    brightness
# 0       254.0
# 1       254.0
# 2       254.0
# 3       254.0
# 4       254.0
# App data shape: (42, 7)

# %%
try:
    with open(DATA_DIR+'/emotion_data.json', 'r') as f:
        manual_data = json.load(f)
    manual_df = pd.DataFrame(manual_data)
    print("Successfully loaded manual emotion data")
    display(manual_df.head())
    print("\nManual data shape:", manual_df.shape)
except Exception as e:
    print(f"Error loading manual data: {e}")
    manual_df = pd.DataFrame()
# Out:
# Successfully loaded manual emotion data
#               timestamp  emotion  valence  arousal
# 0  2025-02-24T19:05:00Z    Happy     0.98     0.55
# 1  2025-02-24T18:12:00Z    Happy     0.99     0.50
# 2  2025-02-24T17:32:00Z    Happy     0.89     0.54
# 3  2025-02-25T19:05:00Z  Excited     0.67     0.76
# 4  2025-02-25T16:53:00Z  Neutral    -0.01    -0.04
# Manual data shape: (57, 4)

# %%
def round_down_to_even_minutes(timestamp):
    """Round down timestamp minutes to nearest even number and format consistently"""
    rounded_minute = timestamp.minute - (timestamp.minute % 2)
    rounded_time = timestamp.replace(minute=rounded_minute, second=0, microsecond=0)
    # Format to match "2025-03-27T17:18:00.000Z" format
    return rounded_time.strftime("%Y-%m-%dT%H:%M:00Z")

# Convert timestamp to datetime if it isn't already
manual_df['timestamp'] = pd.to_datetime(manual_df['timestamp'])

# Apply rounding function and format
manual_df['timestamp'] = manual_df['timestamp'].apply(round_down_to_even_minutes)

# Display the result
display(manual_df.head())
# Out:
#               timestamp  emotion  valence  arousal
# 0  2025-02-24T19:04:00Z    Happy     0.98     0.55
# 1  2025-02-24T18:12:00Z    Happy     0.99     0.50
# 2  2025-02-24T17:32:00Z    Happy     0.89     0.54
# 3  2025-02-25T19:04:00Z  Excited     0.67     0.76
# 4  2025-02-25T16:52:00Z  Neutral    -0.01    -0.04

# %% [markdown]
# # HEALTH DATA FROM GARMIN

# %%
# fetch data from the data/ folder called new_garmin_data.csv
health_data = pd.read_csv('/Users/maudhelenhovland/Desktop/AffectiveLamp/data/new_garmin_data.csv')
print("Successfully loaded health data")
display(health_data.head())
print("\nHealth data shape:", health_data.shape)
# Out:
# Successfully loaded health data
#               timestamp  heart_rate  stress  respiration  body_battery  spo2  \
# 0  2025-04-01T22:00:00Z        62.0    31.0          NaN           NaN  94.0
# 1  2025-04-01T22:02:00Z        64.0    31.0         18.0           NaN  94.0
# 2  2025-04-01T22:04:00Z        63.0    31.0         17.0           NaN  94.0
# 3  2025-04-01T22:06:00Z        64.0    28.0         16.0           NaN  94.0
# 4  2025-04-01T22:08:00Z        65.0    28.0         17.0           NaN  94.0
#
#    hrv  sleep_score
# 0  NaN         50.0
# 1  NaN         50.0
# 2  NaN         50.0
# 3  NaN         50.0
# 4  NaN         50.0
# Health data shape: (22005, 8)

# %%
#Drop columns with negative values
# First, let's identify columns that might have negative values
numeric_columns = health_data.select_dtypes(include=['float64', 'int64']).columns

# Print original shape
print("Original shape:", health_data.shape)

# Drop rows where any numeric column has negative values
for column in numeric_columns:
    # Print number of negative values in each column before dropping
    neg_count = (health_data[column] < 0).sum()
    if neg_count > 0:
        print(f"Found {neg_count} negative values in {column}")
        health_data = health_data[health_data[column] >= 0]

# Print final shape
print("\nShape after removing negative values:", health_data.shape)

# Display the cleaned data
display(health_data.head())
# Out:
# Original shape: (22005, 8)
# Found 4446 negative values in stress
# Found 598 negative values in respiration
#
# Shape after removing negative values: (16931, 8)
#               timestamp  heart_rate  stress  respiration  body_battery  spo2  \
# 1  2025-04-01T22:02:00Z        64.0    31.0         18.0           NaN  94.0
# 2  2025-04-01T22:04:00Z        63.0    31.0         17.0           NaN  94.0
# 3  2025-04-01T22:06:00Z        64.0    28.0         16.0           NaN  94.0
# 4  2025-04-01T22:08:00Z        65.0    28.0         17.0           NaN  94.0
# 5  2025-04-01T22:10:00Z        65.0    28.0         17.0           NaN  94.0
#
#    hrv  sleep_score
# 1  NaN         50.0
# 2  NaN         50.0
# 3  NaN         50.0
# 4  NaN         50.0
# 5  NaN         50.0

# %%
# Check missing values
print("\nMissing values in health data:")
display(health_data.isnull().sum())

# Check for duplicate timestamps
duplicate_timestamps = health_data[health_data.duplicated(subset=['timestamp'])]
# Out:
# Missing values in health data:
# timestamp           0
# heart_rate          3
# stress              0
# respiration         0
# body_battery     2422
# spo2             4273
# hrv             16931
# sleep_score      1909
# dtype: int64

# %% [markdown]
# # Mergin automatic and manual emotion data

# %% [markdown]
# ## MAKE ALL TIMESTAMPS ALIKE

# %%
# Concatenate app_data and manual_df
combined_df = pd.concat([app_data, manual_df], ignore_index=True)

# Sort by timestamp
combined_df = combined_df.sort_values('timestamp')

# Reset index after sorting
combined_df = combined_df.reset_index(drop=True)

# Display the result
display(combined_df.head())
print("\nCombined data shape:", combined_df.shape)
# Out:
#               timestamp  valence  arousal  emotion  hue  saturation  \
# 0  2025-02-24T17:32:00Z     0.89     0.54    Happy  NaN         NaN
# 1  2025-02-24T18:12:00Z     0.99     0.50    Happy  NaN         NaN
# 2  2025-02-24T19:04:00Z     0.98     0.55    Happy  NaN         NaN
# 3  2025-02-25T12:12:00Z     0.03    -0.04  Neutral  NaN         NaN
# 4  2025-02-25T12:36:00Z    -0.07    -0.04    Upset  NaN         NaN
#
#    brightness
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# Combined data shape: (99, 7)

# %%
combined_df.to_csv('/Users/maudhelenhovland/Desktop/AffectiveLamp/data/combined_emotion_data.csv', index=False)

# %% [markdown]
# # WHOLE DATASET

# %%
# Check that all timestamps in combined_df are present in health_data
missing_timestamps = combined_df[~combined_df['timestamp'].isin(health_data['timestamp'])]

# Display the missing timestamps
print("\nMissing timestamps in health data:")
display(missing_timestamps)
# Out:
# Missing timestamps in health data:
#                    timestamp   valence   arousal     emotion      hue  \
# 0       2025-02-24T17:32:00Z  0.890000  0.540000       Happy      NaN
# 1       2025-02-24T18:12:00Z  0.990000  0.500000       Happy      NaN
# 3       2025-02-25T12:12:00Z  0.030000 -0.040000     Neutral      NaN
# 4       2025-02-25T12:36:00Z -0.070000 -0.040000       Upset      NaN
# 5       2025-02-25T12:36:00Z -0.870000  0.640000       Angry      NaN
# 6       2025-02-25T14:30:00Z -0.940000  0.780000       Angry      NaN
# 7       2025-02-25T14:30:00Z -1.030000  0.530000     Annoyed      NaN
# 12      2025-02-26T09:54:00Z -0.080000 -0.050000     Neutral      NaN
# 13      2025-02-26T11:26:00Z -0.030000  0.090000     Neutral      NaN
# 15      2025-02-27T10:36:00Z  0.050000  0.060000     Neutral      NaN
# 20      2025-02-27T18:28:00Z  0.040000  0.070000     Neutral      NaN
# 25      2025-03-04T13:34:00Z -0.970000 -0.650000         Sad      NaN
# 36      2025-03-24T15:48:00Z -0.620000  1.070000     Anxious      NaN
# 41      2025-03-25T13:12:00Z  0.860000  0.480000       Happy      NaN
# 44      2025-03-25T18:24:00Z -0.740000  0.960000     Anxious      NaN
# 46      2025-03-26T12:10:00Z  0.860000  0.600000       Happy      NaN
# 47      2025-03-26T12:40:00Z  0.660000  0.930000     Excited      NaN
# 48      2025-03-26T15:18:00Z -0.700000  1.030000     Anxious      NaN
# 49      2025-03-26T15:34:00Z  0.900000  0.420000       Happy      NaN
# 50      2025-03-26T15:58:00Z -0.270000 -1.120000       Tired      NaN
# 54      2025-03-27T12:40:00Z  1.190000 -0.210000     Pleased      NaN
# 55      2025-03-27T13:32:00Z  0.750000 -0.540000     Content      NaN
# 56      2025-03-27T17:18:00Z  0.537143  0.451429       Happy  21845.0
# 57      2025-03-27T17:20:00Z  0.565714  0.245714       Happy  21845.0
# 58      2025-03-27T17:20:00Z  0.645714  0.474286       Happy  21845.0
# 63      2025-03-27T19:06:00Z -0.560000 -0.694286       Bored  37861.0
# 69      2025-03-28T13:18:00Z  0.794286  0.574286       Happy  21845.0
# 70      2025-03-28T13:20:00Z  0.622857  0.777143     Excited  21845.0
# 74      2025-03-28T16:58:00Z  0.870445  0.492266       Happy  21845.0
# 76      2025-03-31T12:42:00Z  0.651429 -0.385714     Content  10923.0
# 81      2025-04-01T14:04:00Z  0.342857 -0.314286     Content  10923.0
# 84      2025-04-01T16:32:00Z  0.331429 -0.214286     Neutral  10923.0
# 86      2025-04-01T18:14:00Z -0.222857 -0.151429     Neutral  37861.0
# 87      2025-04-02T12:06:00Z  0.617143 -0.442857     Content  10923.0
# 88      2025-04-02T12:08:00Z -0.234286  0.774286       Tense      0.0
# 89      2025-04-02T15:06:00Z  0.342857  0.345714   Confident  21845.0
# 90      2025-04-02T15:12:00Z -0.222857  0.182857     Neutral      0.0
# 91      2025-04-02T15:18:00Z -0.445714 -0.497143       Bored  37861.0
# 92      2025-04-02T15:36:00Z -0.337143  0.462857     Neutral      0.0
# 93      2025-04-02T16:00:00Z -0.297143 -0.091429     Neutral  37861.0
# 94      2025-04-02T16:02:00Z -0.571429  0.340000     Annoyed      0.0
# 95      2025-04-02T16:04:00Z -0.588571  0.197143  Frustrated      0.0
# 96      2025-04-02T16:04:00Z -0.285714  0.425714     Neutral      0.0
# 97      2025-04-02T16:08:00Z -0.102857 -0.865714       Tired  37861.0
# 98  2025-04-07T14:02:00:000Z  0.108571  0.002857     Neutral      0.0
#
#     saturation  brightness
# 0          NaN         NaN
# 1          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 15         NaN         NaN
# 20         NaN         NaN
# 25         NaN         NaN
# 36         NaN         NaN
# 41         NaN         NaN
# 44         NaN         NaN
# 46         NaN         NaN
# 47         NaN         NaN
# 48         NaN         NaN
# 49         NaN         NaN
# 50         NaN         NaN
# 54         NaN         NaN
# 55         NaN         NaN
# 56       254.0       254.0
# 57       254.0       254.0
# 58       254.0       254.0
# 63       222.0       254.0
# 69       254.0       254.0
# 70       254.0       254.0
# 74       254.0         NaN
# 76       254.0       254.0
# 81       254.0       254.0
# 84       254.0       254.0
# 86       222.0       254.0
# 87       254.0       254.0
# 88       254.0       254.0
# 89       254.0       254.0
# 90       254.0       254.0
# 91       222.0       254.0
# 92       254.0       254.0
# 93       222.0       254.0
# 94       254.0       254.0
# 95       254.0       254.0
# 96       254.0       254.0
# 97       222.0       254.0
# 98         0.0       116.0

# %%
# Check datatypes in combined_df
print("\nDatatypes in combined_df:")
display(combined_df.dtypes)

# Check for duplicate timestamps in combined_df
duplicate_timestamps = combined_df[combined_df.duplicated(subset=['timestamp'])]
# Out:
# Datatypes in combined_df:
# timestamp      object
# valence       float64
# arousal       float64
# emotion        object
# hue           float64
# saturation    float64
# brightness    float64
# dtype: object

# %%
#Check datatypes in health_data
print("\nDatatypes in health_data:")
display(health_data.dtypes)

#Check for duplicate timestamps in health_data
duplicate_timestamps = health_data[health_data.duplicated(subset=['timestamp'])]
# Out:
# Datatypes in health_data:
# timestamp        object
# heart_rate      float64
# stress          float64
# respiration     float64
# body_battery    float64
# spo2            float64
# hrv             float64
# sleep_score     float64
# dtype: object

# %%
#merge on timestamps with the health_data and app_and_manual_data
merged_data = pd.merge(health_data, combined_df, on='timestamp', how='left')
display(merged_data.head())
# Out:
#               timestamp  heart_rate  stress  respiration  body_battery  spo2  \
# 0  2025-04-01T22:02:00Z        64.0    31.0         18.0           NaN  94.0
# 1  2025-04-01T22:04:00Z        63.0    31.0         17.0           NaN  94.0
# 2  2025-04-01T22:06:00Z        64.0    28.0         16.0           NaN  94.0
# 3  2025-04-01T22:08:00Z        65.0    28.0         17.0           NaN  94.0
# 4  2025-04-01T22:10:00Z        65.0    28.0         17.0           NaN  94.0
#
#    hrv  sleep_score  valence  arousal emotion  hue  saturation  brightness
# 0  NaN         50.0      NaN      NaN     NaN  NaN         NaN         NaN
# 1  NaN         50.0      NaN      NaN     NaN  NaN         NaN         NaN
# 2  NaN         50.0      NaN      NaN     NaN  NaN         NaN         NaN
# 3  NaN         50.0      NaN      NaN     NaN  NaN         NaN         NaN
# 4  NaN         50.0      NaN      NaN     NaN  NaN         NaN         NaN

# %%
#Save as a csv file
merged_data.to_csv('/Users/maudhelenhovland/Desktop/AffectiveLamp/data/merged_data.csv', index=False)
